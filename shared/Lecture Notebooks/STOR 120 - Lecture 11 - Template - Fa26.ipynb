# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Comparison ##

# %%
3 > 1

# %%
type(3 > 1)

# %%
True

# %%
true

# %%
3 = 3

# %%
3 == 3.0

# %%
10 != 2

# %%
x = 14
y = 3

# %%
x > 15

# %%
12 < x

# %%
x < 20

# %%
12 < x < 20

# %%
10 < x-y < 13

# %%
x > 13 and y < 3.14159

# %%
x > 13 or y < 3.14159

# %% [markdown]
# ## Comparisons with arrays

# %%
grades = make_array('A', 'B', 'C', 'A', 'A')

# %% [markdown]
# ## Simulation

# %% [markdown]
# Let's play a game: we each roll a die.
#
# If my number is bigger: you pay me a dollar.
#
# If they're the same: we do nothing.
#
# If your number is bigger: I pay you a dollar.

# %% [markdown]
# Steps:
# 1. Find a way to simulate two dice rolls.
# 2. Compute how much money we win/lose based on the result.
# 3. Do steps 1 and 2 10,000 times.

# %% [markdown]
# ### Conditional Statements

# %%
# Work in progress

# %%
# Final correct version

# %% [markdown]
# ### Random Selection

# %%
guess = make_array('right', 'wrong')

# %% [markdown]
# ### Appending Arrays

# %%
first = np.arange(4)
second = np.arange(10, 17)

# %% [markdown]
# ### Repeated Betting ###

# %% [markdown]
# ## `For` Statements

# %%
i = make_array('A', 'B', 'C', 'A', 'A').item(0)
print('I got a ' + i + "!")

i = make_array('A', 'B', 'C', 'A', 'A').item(1)
print('I got a ' + i + "!")

i = make_array('A', 'B', 'C', 'A', 'A').item(2)
print('I got a ' + i + "!")

i = make_array('A', 'B', 'C', 'A', 'A').item(3)
print('I got a ' + i + "!")

i = make_array('A', 'B', 'C', 'A', 'A').item(4)
print('I got a ' + i + "!")
