# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Census ##

# %%
census = Table.read_table('/home/jovyan/shared/Data/nc-est2021-agesex-res.csv')

census = census.drop(
    'POPESTIMATE2020').relabeled(
    'ESTIMATESBASE2020', '2020').relabeled(
    'POPESTIMATE2021', '2021')

census

# %%
no_999 = census.where('AGE', are.below(999))
everyone = no_999.where('SEX', 0).drop('SEX')

# %% [markdown]
# ## Line Plots ##

# %% [markdown]
# ## What proportion of each age group were female in 2020?

# %%
females_uspop_2020 = ...
females_uspop_2020

# %%
prop_female_uspop_2020 = Table().with_columns(
    'AGE',
    ...,
    'Proportion Female',
    ...
)

prop_female_uspop_2020

# %% [markdown]
# ## Scatter Plots ##

# %%
insurance = Table.read_table('/home/jovyan/shared/Data/insurance_charges.csv')
insurance

# %% [markdown]
# ## Bar Charts ##

# %%
vgsales = Table.read_table('/home/jovyan/shared/Data/vgsales.csv')
vgsales

# %%
# Generate the chart shown in the slides:
# bar chart of age (# years since release) for the 10 highest grossing global sales for Nintendo games
