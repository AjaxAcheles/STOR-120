# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Categorical Distribution ##

# %%
vgsales = Table.read_table('/home/jovyan/shared/Data/vgsales.csv')
vgsales

# %%
# New years_since variable


# Add years_since column to table


# Select Nintendo, sort by global sales, and make new table with 10 largest global sales


# Barplot for the years since release of games by name

# %% [markdown]
# ## Bar Charts ##

# %% [markdown]
# ## Numerical Distribution - Binning

# %% [markdown]
# ## Histograms ##

# %%
# Let's make our first histogram!

# %%
# Let's try equally spaced bins instead.

# %%
# Let's try not specifying any bins!

# %%
# Add a column containing what percent of games are in each bin

# %% [markdown]
# ## Height ##
#
# ### Question: What is the height of the [20, 30) bin?

# %%
# Step 1: Calculate % of games in the [20, 30) bin
percent = ...
percent

# %%
# Step 2: Calculate the width of the 20-30 bin
width = ...

# %%
# Step 3: Area of rectangle = height * width
#         --> height = percent / width
height = ...
height
