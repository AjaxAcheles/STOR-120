# %%
from datascience import *

# %% [markdown]
# ## Python ##

# %%
2 + 9

# %%
2 * 9

# %%
2 / 9

# %%
2 + 3 * 9

# %%
(2 + 3) * 9

# %%
2 ** 4

# %%
'hello'

# %% [markdown]
# ## Names ##

# %%
a = 4

# %%
a

# %%
b = 9

# %%
b

# %%
a * 3

# %%
total = a + b

# %%
total

# %%
a = 10

# %%
total

# %%
total = a + b

# %%
total

# %%
'total'

# %% [markdown]
# ## Functions and Call Expressions

# %%
abs(-5)

# %%
abs(1 - 3)

# %%
i = 52
j = 47
abs(j - i)

# %%
min(14, 15)

# %%
round(123.456)

# %%
round(123.456, 1)

# %%
round(123.456, ndigits=1)

# %% [markdown]
# ## Tables

# %%
songs2 = Table.read_table('/home/jovyan/shared/Data/songs2.csv')
songs2

# %%
songs2.show(3)

# %%
songs2.show(100)

# %%
songs2.select('artist')

# %%
songs2.select('artist', 'name')

# %%
songs2.select(artist, 'name')

# %%
songs2.drop('duration')

# %%
songs2

# %%
songs2_without_duration = songs2.drop('duration')
songs2_without_duration

# %%
songs2.where('artist', '"Weird Al" Yankovic')

# %%
songs2.where('duration', 240)

# %%
songs2.sort('duration')

# %%
songs2.sort('duration', descending = True)

# %% [markdown]
# ## Another table

# %%
Arrests = Table.read_table('/home/jovyan/shared/Data/Police_Arrests_Made.csv')
Arrests

# %%
Arrests.where('Primary_Charge', 'OPEN CONTAINER')

# %%
Arrests.where('City', 'CHAPEL HILL')

# %%
Arrests.where('City', 'CHAPEL HILL').sort('Age')

# %%
Arrests.where('City', 'CHAPEL HILL').sort('Age', descending=True)
