# %%
from datascience import *

# %% [markdown]
# ## Python ##

# %%
songs2 = Table.read_table('/home/jovyan/shared/Data/songs2.csv')
songs2
# Out:
# name                          | artist         | duration
# The Little Things             | Colbie Caillat | 225
# The Regality Dance            | Elvenking      | 347
# Come Out Swinging             | The Offspring  | 167
# You Make Me Like Charity      | The Knife      | 185
# Cat People (Putting Out Fire) | David Bowie    | 402
# Attack The Doctor             | Blockhead      | 346
# Sorry But It's Over           | dredg          | 249
# Scarlette                     | Sevdaliza      | 205
# Green Mind                    | Dinosaur Jr.   | 299
# Whoever She Is                | The Maine      | 221
# ... (22485 rows omitted)

# %%
1+2
# Out:
# 3

# %%
3 == 3
# Out:
# True

# %%
2-3
# Out:
# -1

# %% [markdown]
# ## Names ##

# %%
status = True

# %%
if status == True:
    print(status)
# Out:
# True

# %% [markdown]
# ## Functions and Call Expressions

# %%
def max(x, y):
    if x < y:
        return y
    elif x > y:
        return x
    else: 
        return None 

def abs(x):
    if x < 0:
        return -x
    else:
        return x

# %%
max(1,4)
# Out:
# 4

# %%
max(4,1)
# Out:
# 4

# %%
max(4,4)

# %% [markdown]
# ## Tables

# %%
songs2 = Table.read_table('/home/jovyan/shared/Data/songs2.csv')
songs2
# Out:
# name                          | artist         | duration
# The Little Things             | Colbie Caillat | 225
# The Regality Dance            | Elvenking      | 347
# Come Out Swinging             | The Offspring  | 167
# You Make Me Like Charity      | The Knife      | 185
# Cat People (Putting Out Fire) | David Bowie    | 402
# Attack The Doctor             | Blockhead      | 346
# Sorry But It's Over           | dredg          | 249
# Scarlette                     | Sevdaliza      | 205
# Green Mind                    | Dinosaur Jr.   | 299
# Whoever She Is                | The Maine      | 221
# ... (22485 rows omitted)

# %%
songs2.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>artist</th> <th>duration</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>The Little Things </td> <td>Colbie Caillat</td> <td>225     </td>
#         </tr>
#         <tr>
#             <td>The Regality Dance</td> <td>Elvenking     </td> <td>347     </td>
#         </tr>
#         <tr>
#             <td>Come Out Swinging </td> <td>The Offspring </td> <td>167     </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (22492 rows omitted)</p>

# %% [markdown]
# ## Another table

# %%
Arrests = Table.read_table('/home/jovyan/shared/Data/Police_Arrests_Made.csv')
Arrests
