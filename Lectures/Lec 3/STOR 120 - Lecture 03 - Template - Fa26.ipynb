# %%
from datascience import *
import numpy as np

# %% [markdown]
# ## Review of Tables ##

# %%
skyscrapers = Table.read_table('/home/jovyan/shared/Data/skyscrapers.csv')
skyscrapers

# %%
skyscrapers.select('name', 'height')

# %%
skyscrapers.drop('completed', 'height', 'material')

# %%
skyscrapers

# %%
skyscrapers.where('city', 'Charlotte')

# %%
skyscrapers.where('name', 'Empire State Building')

# %%
skyscrapers.where('city', 'New York City').sort('completed')

# %%
skyscrapers.where('city', 'New York City').sort('completed', descending=True)

# %%
chicago = skyscrapers.where('city', 'Chicago').drop('city')
chicago

# %%
chicago.where('material', 'steel').sort('completed', descending=True)

# %% [markdown]
# ## Numbers ##

# %% [markdown]
# ## Strings ##

# %% [markdown]
# ## Types ##

# %% [markdown]
# ## Arrays ##

# %% [markdown]
# ## Columns of Tables are Arrays ##

# %%
Arrests_Carrboro = Table.read_table('/home/jovyan/shared/Data/Police_Arrests_Made.csv').where('City', 'CARRBORO')

Arrests_Carrboro

# %%
CH_OP = ...
CH_OP

# %%
# what is the average age of open container arrests in Chapel Hill

# %%
# Do the same for Carrboro
