# %% [markdown]
# # STOR 120: Class 4 - Building Tables

# %%
from datascience import *
import numpy as np

# %% [markdown]
# ## Arrays

# %%
heights = make_array(10, 50, 70, 25)
heights
# Out:
# array([10, 50, 70, 25])

# %%
sum(heights)
# Out:
# 155

# %% [markdown]
# ## Ranges ##

# %% [markdown]
# ## Creating a Table from Scratch ##

# %% [markdown]
# ### Minard ###

# %% [markdown]
# What percentage of Napoleon’s troops were still alive in each city of the advance and retreat?
